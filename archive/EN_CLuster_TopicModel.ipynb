# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
read_df = pd.read_parquet('twitter_data.parquet')
read_df.head()
# Out:
#                   timestamp             tweet_id      conversation_id  \
# 0  2021-06-20T21:33:30.000Z  1406726930888540160  1406726930888540160
# 1  2021-06-20T21:29:24.000Z  1406725899744157698  1406725899744157698
# 2  2021-06-20T20:50:42.000Z  1406716159064485895  1406716159064485895
# 3  2021-06-20T17:56:03.000Z  1406672208056012807  1406672208056012807
# 4  2021-06-20T17:53:00.000Z  1406671439328055301  1406671439328055301
#
#     author_id                                               text  \
# 0  2981738470  RT @davidlohner: #IchbinHanna und schreibe auc...
# 1  2981738470  Wenn Wirtschaftsjounalist:innen über #IchbinHa...
# 2  2981738470  RT @DrKEichhorn: Wieder ein Artikel ohne echte...
# 3  2981738470  RT @chrismeyer2203: So sieht es aus ⬇️ oder an...
# 4  2981738470  RT @steffen_siegel: Modelle einer Universitäts...
#
#    retweet_count  reply_count  like_count  quote_count  \
# 0              7            0           0            0
# 1              9            1          62            4
# 2             16            0           0            0
# 3              7            0           0            0
# 4             17            0           0            0
#
#                                    referenced_tweets         hashtags  \
# 0  [{'type': 'retweeted', 'id': '1406714909258362...  ['IchbinHanna']
# 1                                                 []  ['IchbinHanna']
# 2  [{'type': 'retweeted', 'id': '1406697315159752...               []
# 3  [{'type': 'retweeted', 'id': '1406175728190865...               []
# 4  [{'type': 'retweeted', 'id': '1406666454368493...               []
#
#   tweet_type tweet_language
# 0    retweet             de
# 1   original             de
# 2    retweet             de
# 3    retweet             de
# 4    retweet             de

# %%
read_df = read_df.drop_duplicates(subset=['tweet_id'])
read_df.shape
# Out:
# (181552, 13)

# %%
read_df['tweet_language'].value_counts()
# Out:
# de         159811
# en          18586
# sv           1296
# nl            345
# fr            314
# tl            195
# cy            181
# it            166
# id            159
# unknown       120
# es             51
# ja             49
# fi             33
# no             28
# pl             28
# sw             24
# pt             22
# af             19
# et             17
# ca             16
# so             14
# da             14
# tr             11
# ro             11
# cs              7
# ar              7
# sl              6
# hr              5
# sk              4
# vi              3
# hi              2
# fa              2
# hu              2
# th              1
# sq              1
# ru              1
# lv              1
# Name: tweet_language, dtype: int64

# %%
read_df = read_df.loc[read_df['tweet_type'] != 'retweet']
read_df.head()
# Out:
#                    timestamp             tweet_id      conversation_id  \
# 1   2021-06-20T21:29:24.000Z  1406725899744157698  1406725899744157698
# 5   2021-06-20T16:17:25.000Z  1406647386542325764  1406647386542325764
# 11  2021-06-18T13:10:36.000Z  1405875593711964166  1405875593711964166
# 16  2021-06-18T10:21:31.000Z  1405833045224087555  1405833045224087555
# 19  2021-06-18T08:35:29.000Z  1405806358335832065  1405806358335832065
#
#               author_id                                               text  \
# 1            2981738470  Wenn Wirtschaftsjounalist:innen über #IchbinHa...
# 5            2981738470  ☝️⬇️ #IchbinHanna #PeerReview https://t.co/PFN...
# 11  1132055796571877376  Thread ⬇️ about the cruel #precarity in German...
# 16            242424959  Liebe @unidue und Forsa - schön, dass ihr euch...
# 19  1132055796571877376  Wichtiger Thread ⬇️ zu #Machtmissbrauch in der...
#
#     retweet_count  reply_count  like_count  quote_count  \
# 1               9            1          62            4
# 5               0            0           1            0
# 11              5            0          19            0
# 16              0            1           2            0
# 19              2            0          13            0
#
#                                     referenced_tweets  \
# 1                                                  []
# 5   [{'type': 'quoted', 'id': '1406620276822061057'}]
# 11  [{'type': 'quoted', 'id': '1405846267759054851'}]
# 16                                                 []
# 19  [{'type': 'quoted', 'id': '1405494574533984264'}]
#
#                                              hashtags tweet_type  \
# 1                                     ['IchbinHanna']   original
# 5                       ['IchbinHanna', 'PeerReview']   original
# 11  ['precarity', 'academia', 'IchbinHanna', 'Acad...   original
# 16                       ['Mittelbau', 'IchBinHanna']   original
# 19  ['Machtmissbrauch', 'Wissenschaft', 'prekär', ...   original
#
#    tweet_language
# 1              de
# 5              nl
# 11             en
# 16             de
# 19             de

# %%
import re
def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)

read_df.text = read_df.text.apply(remove_emojis)
read_df.head()
# Out:
#                    timestamp             tweet_id      conversation_id  \
# 1   2021-06-20T21:29:24.000Z  1406725899744157698  1406725899744157698
# 5   2021-06-20T16:17:25.000Z  1406647386542325764  1406647386542325764
# 11  2021-06-18T13:10:36.000Z  1405875593711964166  1405875593711964166
# 16  2021-06-18T10:21:31.000Z  1405833045224087555  1405833045224087555
# 19  2021-06-18T08:35:29.000Z  1405806358335832065  1405806358335832065
#
#               author_id                                               text  \
# 1            2981738470  Wenn Wirtschaftsjounalist:innen über #IchbinHa...
# 5            2981738470   #IchbinHanna #PeerReview https://t.co/PFNrovEOAS
# 11  1132055796571877376  Thread  about the cruel #precarity in German #...
# 16            242424959  Liebe @unidue und Forsa - schön, dass ihr euch...
# 19  1132055796571877376  Wichtiger Thread  zu #Machtmissbrauch in der #...
#
#     retweet_count  reply_count  like_count  quote_count  \
# 1               9            1          62            4
# 5               0            0           1            0
# 11              5            0          19            0
# 16              0            1           2            0
# 19              2            0          13            0
#
#                                     referenced_tweets  \
# 1                                                  []
# 5   [{'type': 'quoted', 'id': '1406620276822061057'}]
# 11  [{'type': 'quoted', 'id': '1405846267759054851'}]
# 16                                                 []
# 19  [{'type': 'quoted', 'id': '1405494574533984264'}]
#
#                                              hashtags tweet_type  \
# 1                                     ['IchbinHanna']   original
# 5                       ['IchbinHanna', 'PeerReview']   original
# 11  ['precarity', 'academia', 'IchbinHanna', 'Acad...   original
# 16                       ['Mittelbau', 'IchBinHanna']   original
# 19  ['Machtmissbrauch', 'Wissenschaft', 'prekär', ...   original
#
#    tweet_language
# 1              de
# 5              nl
# 11             en
# 16             de
# 19             de

# %%
def remove_mentions_and_tags(text): #Removing mentions and hashtags and url
    text = re.sub(r'@\S*', '', text)
    text = re.sub(r'http\S+', '', text)
    return re.sub(r'#\S*', '', text)

read_df.text = read_df.text.apply(remove_mentions_and_tags)

# %%
read_df['text'] = read_df['text'].str.replace(r'[^\w\s]+', '') #remove punctuations
# Out:
# C:\Users\Moinam\AppData\Local\Temp\ipykernel_13908\2773504966.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   read_df['text'] = read_df['text'].str.replace(r'[^\w\s]+', '') #remove punctuations

# %%
read_df['text'] = read_df['text'].str.replace('\d+', '') #removes number
# Out:
# C:\Users\Moinam\AppData\Local\Temp\ipykernel_13908\2955464902.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   read_df['text'] = read_df['text'].str.replace('\d+', '') #removes number

# %%
#English

# %%
en_df = read_df[read_df.tweet_language == 'en']
en_df.head()
# Out:
#                     timestamp             tweet_id      conversation_id  \
# 11   2021-06-18T13:10:36.000Z  1405875593711964166  1405875593711964166
# 105  2021-06-12T21:15:23.000Z  1403823267115376649  1403823267115376649
# 125  2021-06-11T22:32:52.000Z  1403480380632674307  1403480380632674307
# 215  2021-06-10T19:07:52.000Z  1403066401611472902  1403066401611472902
# 238  2021-06-10T15:04:44.000Z  1403005214974640143  1403005214974640143
#
#                author_id                                               text  \
# 11   1132055796571877376  Thread  about the cruel  in German  The debate...
# 105  1132055796571877376  Thread  summarizing a video by the German Fede...
# 125  1132055796571877376  On job  in German  and its impact on  life and...
# 215  1132055796571877376
# 238  1132055796571877376   German researchers without a permanent post i...
#
#      retweet_count  reply_count  like_count  quote_count  \
# 11               5            0          19            0
# 105              1            0           9            1
# 125              0            0           1            0
# 215              0            0           1            0
# 238              7            0          15            0
#
#                                      referenced_tweets  \
# 11   [{'type': 'quoted', 'id': '1405846267759054851'}]
# 105  [{'type': 'quoted', 'id': '1403006909079293953'}]
# 125  [{'type': 'quoted', 'id': '1402963684691955714'}]
# 215  [{'type': 'quoted', 'id': '1403059508021284864'}]
# 238  [{'type': 'quoted', 'id': '1402994337009442820'}]
#
#                                               hashtags tweet_type  \
# 11   ['precarity', 'academia', 'IchbinHanna', 'Acad...   original
# 105  ['IchbinHanna', 'academia', 'Germany', 'toxica...   original
# 125  ['precarity', 'academia', 'family', 'mentalhea...   original
# 215  ['AcademicTwitter', 'acertaindegreeofflexibili...   original
# 238  ['IchbinHanna', 'academia', 'AcademicTwitter',...   original
#
#     tweet_language
# 11              en
# 105             en
# 125             en
# 215             en
# 238             en

# %%
# !pip install HanTa
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: HanTa in c:\users\moinam\appdata\local\programs\python\python310\lib\site-packages (1.0.0)

# %%
#getting nouns and adjectives
import nltk
nltk.download('punkt')
from HanTa import HanoverTagger as ht

en_tagger = ht.HanoverTagger('morphmodel_en.pgz')

def en_noun(text):
  words = nltk.word_tokenize(text)
  tokens=[word for (word,x,pos) in en_tagger.tag_sent(words,taglevel= 1) if pos == 'NN']
  return tokens

def en_adj(text):
  words = nltk.word_tokenize(text)
  tokens=[word for (word,x,pos) in en_tagger.tag_sent(words,taglevel= 1) if pos == 'ADJ']
  return tokens

en_df['en_noun'] = en_df.text.apply(en_noun)
en_df['en_adj'] = en_df.text.apply(en_adj)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Moinam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# C:\Users\Moinam\AppData\Local\Temp\ipykernel_13908\2603410340.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_df['en_noun'] = en_df.text.apply(en_noun)
# C:\Users\Moinam\AppData\Local\Temp\ipykernel_13908\2603410340.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_df['en_adj'] = en_df.text.apply(en_adj)

# %%
en_df.head()
# Out:
#                     timestamp             tweet_id      conversation_id  \
# 11   2021-06-18T13:10:36.000Z  1405875593711964166  1405875593711964166
# 105  2021-06-12T21:15:23.000Z  1403823267115376649  1403823267115376649
# 125  2021-06-11T22:32:52.000Z  1403480380632674307  1403480380632674307
# 215  2021-06-10T19:07:52.000Z  1403066401611472902  1403066401611472902
# 238  2021-06-10T15:04:44.000Z  1403005214974640143  1403005214974640143
#
#                author_id                                               text  \
# 11   1132055796571877376  Thread  about the cruel  in German  The debate...
# 105  1132055796571877376  Thread  summarizing a video by the German Fede...
# 125  1132055796571877376  On job  in German  and its impact on  life and...
# 215  1132055796571877376
# 238  1132055796571877376   German researchers without a permanent post i...
#
#      retweet_count  reply_count  like_count  quote_count  \
# 11               5            0          19            0
# 105              1            0           9            1
# 125              0            0           1            0
# 215              0            0           1            0
# 238              7            0          15            0
#
#                                      referenced_tweets  \
# 11   [{'type': 'quoted', 'id': '1405846267759054851'}]
# 105  [{'type': 'quoted', 'id': '1403006909079293953'}]
# 125  [{'type': 'quoted', 'id': '1402963684691955714'}]
# 215  [{'type': 'quoted', 'id': '1403059508021284864'}]
# 238  [{'type': 'quoted', 'id': '1402994337009442820'}]
#
#                                               hashtags tweet_type  \
# 11   ['precarity', 'academia', 'IchbinHanna', 'Acad...   original
# 105  ['IchbinHanna', 'academia', 'Germany', 'toxica...   original
# 125  ['precarity', 'academia', 'family', 'mentalhea...   original
# 215  ['AcademicTwitter', 'acertaindegreeofflexibili...   original
# 238  ['IchbinHanna', 'academia', 'AcademicTwitter',...   original
#
#     tweet_language                                            en_noun en_adj
# 11              en                                   [Thread, debate]     []
# 105             en  [Thread, video, Ministry, Education, Research,...     []
# 125             en                                [job, impact, life]     []
# 215             en                                                 []     []
# 238             en  [post, comment, job, Ministry, Education, Rese...     []

# %%
en_df.en_adj.unique
# Out:
# <bound method Series.unique of 11        []
# 105       []
# 125       []
# 215       []
# 238       []
#           ..
# 308092    []
# 308243    []
# 308292    []
# 308293    []
# 308323    []
# Name: en_adj, Length: 6129, dtype: object>

# %%
def to_lowercase(text):
  token = []
  for i in range(len(text)):
    val = text[i].lower()
    token.append(val)
  return token

en_df.en_noun = en_df.en_noun.apply(to_lowercase)

en_df.head()
# Out:
# C:\Users\Moinam\AppData\Local\Temp\ipykernel_13908\2124371995.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_df.en_noun = en_df.en_noun.apply(to_lowercase)
#                     timestamp             tweet_id      conversation_id  \
# 11   2021-06-18T13:10:36.000Z  1405875593711964166  1405875593711964166
# 105  2021-06-12T21:15:23.000Z  1403823267115376649  1403823267115376649
# 125  2021-06-11T22:32:52.000Z  1403480380632674307  1403480380632674307
# 215  2021-06-10T19:07:52.000Z  1403066401611472902  1403066401611472902
# 238  2021-06-10T15:04:44.000Z  1403005214974640143  1403005214974640143
#
#                author_id                                               text  \
# 11   1132055796571877376  Thread  about the cruel  in German  The debate...
# 105  1132055796571877376  Thread  summarizing a video by the German Fede...
# 125  1132055796571877376  On job  in German  and its impact on  life and...
# 215  1132055796571877376
# 238  1132055796571877376   German researchers without a permanent post i...
#
#      retweet_count  reply_count  like_count  quote_count  \
# 11               5            0          19            0
# 105              1            0           9            1
# 125              0            0           1            0
# 215              0            0           1            0
# 238              7            0          15            0
#
#                                      referenced_tweets  \
# 11   [{'type': 'quoted', 'id': '1405846267759054851'}]
# 105  [{'type': 'quoted', 'id': '1403006909079293953'}]
# 125  [{'type': 'quoted', 'id': '1402963684691955714'}]
# 215  [{'type': 'quoted', 'id': '1403059508021284864'}]
# 238  [{'type': 'quoted', 'id': '1402994337009442820'}]
#
#                                               hashtags tweet_type  \
# 11   ['precarity', 'academia', 'IchbinHanna', 'Acad...   original
# 105  ['IchbinHanna', 'academia', 'Germany', 'toxica...   original
# 125  ['precarity', 'academia', 'family', 'mentalhea...   original
# 215  ['AcademicTwitter', 'acertaindegreeofflexibili...   original
# 238  ['IchbinHanna', 'academia', 'AcademicTwitter',...   original
#
#     tweet_language                                            en_noun en_adj
# 11              en                                   [thread, debate]     []
# 105             en  [thread, video, ministry, education, research,...     []
# 125             en                                [job, impact, life]     []
# 215             en                                                 []     []
# 238             en  [post, comment, job, ministry, education, rese...     []

# %%
en_df.en_adj = en_df.en_adj.apply(to_lowercase)
# Out:
# C:\Users\Moinam\AppData\Local\Temp\ipykernel_13908\736935701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_df.en_adj = en_df.en_adj.apply(to_lowercase)

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords

english_stop_words = stopwords.words('english')
english_stop_words.append('amp')

def stop_word_en_removal(x):
    return ' '.join([w for w in x if not w in english_stop_words])

en_df.en_noun = en_df.en_noun.apply(stop_word_en_removal)
en_df.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Moinam\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Moinam\AppData\Local\Temp\ipykernel_13908\1942927101.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_df.en_noun = en_df.en_noun.apply(stop_word_en_removal)
#                     timestamp             tweet_id      conversation_id  \
# 11   2021-06-18T13:10:36.000Z  1405875593711964166  1405875593711964166
# 105  2021-06-12T21:15:23.000Z  1403823267115376649  1403823267115376649
# 125  2021-06-11T22:32:52.000Z  1403480380632674307  1403480380632674307
# 215  2021-06-10T19:07:52.000Z  1403066401611472902  1403066401611472902
# 238  2021-06-10T15:04:44.000Z  1403005214974640143  1403005214974640143
#
#                author_id                                               text  \
# 11   1132055796571877376  Thread  about the cruel  in German  The debate...
# 105  1132055796571877376  Thread  summarizing a video by the German Fede...
# 125  1132055796571877376  On job  in German  and its impact on  life and...
# 215  1132055796571877376
# 238  1132055796571877376   German researchers without a permanent post i...
#
#      retweet_count  reply_count  like_count  quote_count  \
# 11               5            0          19            0
# 105              1            0           9            1
# 125              0            0           1            0
# 215              0            0           1            0
# 238              7            0          15            0
#
#                                      referenced_tweets  \
# 11   [{'type': 'quoted', 'id': '1405846267759054851'}]
# 105  [{'type': 'quoted', 'id': '1403006909079293953'}]
# 125  [{'type': 'quoted', 'id': '1402963684691955714'}]
# 215  [{'type': 'quoted', 'id': '1403059508021284864'}]
# 238  [{'type': 'quoted', 'id': '1402994337009442820'}]
#
#                                               hashtags tweet_type  \
# 11   ['precarity', 'academia', 'IchbinHanna', 'Acad...   original
# 105  ['IchbinHanna', 'academia', 'Germany', 'toxica...   original
# 125  ['precarity', 'academia', 'family', 'mentalhea...   original
# 215  ['AcademicTwitter', 'acertaindegreeofflexibili...   original
# 238  ['IchbinHanna', 'academia', 'AcademicTwitter',...   original
#
#     tweet_language                                            en_noun en_adj
# 11              en                                      thread debate     []
# 105             en  thread video ministry education research outcr...     []
# 125             en                                    job impact life     []
# 215             en                                                        []
# 238             en  post comment job ministry education research s...     []

# %%
en_df.en_adj = en_df.en_adj.apply(stop_word_en_removal)
en_df.head()
# Out:
# C:\Users\Moinam\AppData\Local\Temp\ipykernel_13908\3399689501.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_df.en_adj = en_df.en_adj.apply(stop_word_en_removal)
#                     timestamp             tweet_id      conversation_id  \
# 11   2021-06-18T13:10:36.000Z  1405875593711964166  1405875593711964166
# 105  2021-06-12T21:15:23.000Z  1403823267115376649  1403823267115376649
# 125  2021-06-11T22:32:52.000Z  1403480380632674307  1403480380632674307
# 215  2021-06-10T19:07:52.000Z  1403066401611472902  1403066401611472902
# 238  2021-06-10T15:04:44.000Z  1403005214974640143  1403005214974640143
#
#                author_id                                               text  \
# 11   1132055796571877376  Thread  about the cruel  in German  The debate...
# 105  1132055796571877376  Thread  summarizing a video by the German Fede...
# 125  1132055796571877376  On job  in German  and its impact on  life and...
# 215  1132055796571877376
# 238  1132055796571877376   German researchers without a permanent post i...
#
#      retweet_count  reply_count  like_count  quote_count  \
# 11               5            0          19            0
# 105              1            0           9            1
# 125              0            0           1            0
# 215              0            0           1            0
# 238              7            0          15            0
#
#                                      referenced_tweets  \
# 11   [{'type': 'quoted', 'id': '1405846267759054851'}]
# 105  [{'type': 'quoted', 'id': '1403006909079293953'}]
# 125  [{'type': 'quoted', 'id': '1402963684691955714'}]
# 215  [{'type': 'quoted', 'id': '1403059508021284864'}]
# 238  [{'type': 'quoted', 'id': '1402994337009442820'}]
#
#                                               hashtags tweet_type  \
# 11   ['precarity', 'academia', 'IchbinHanna', 'Acad...   original
# 105  ['IchbinHanna', 'academia', 'Germany', 'toxica...   original
# 125  ['precarity', 'academia', 'family', 'mentalhea...   original
# 215  ['AcademicTwitter', 'acertaindegreeofflexibili...   original
# 238  ['IchbinHanna', 'academia', 'AcademicTwitter',...   original
#
#     tweet_language                                            en_noun en_adj
# 11              en                                      thread debate
# 105             en  thread video ministry education research outcr...
# 125             en                                    job impact life
# 215             en
# 238             en  post comment job ministry education research s...

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Moinam\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Moinam\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
#lemmatizer
import nltk
import pandas as pd

w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
  return [lemmatizer.lemmatize(w,'v') for w in w_tokenizer.tokenize(text)]

en_df['text_lemmatized_adj'] = en_df.en_adj.apply(lemmatize_text)
en_df['text_lemmatized_noun'] = en_df.en_noun.apply(lemmatize_text)
# Out:
# C:\Users\Moinam\AppData\Local\Temp\ipykernel_13908\1871320948.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_df['text_lemmatized_adj'] = en_df.en_adj.apply(lemmatize_text)
# C:\Users\Moinam\AppData\Local\Temp\ipykernel_13908\1871320948.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_df['text_lemmatized_noun'] = en_df.en_noun.apply(lemmatize_text)

# %%
en_df.head()
# Out:
#                     timestamp             tweet_id      conversation_id  \
# 11   2021-06-18T13:10:36.000Z  1405875593711964166  1405875593711964166
# 105  2021-06-12T21:15:23.000Z  1403823267115376649  1403823267115376649
# 125  2021-06-11T22:32:52.000Z  1403480380632674307  1403480380632674307
# 215  2021-06-10T19:07:52.000Z  1403066401611472902  1403066401611472902
# 238  2021-06-10T15:04:44.000Z  1403005214974640143  1403005214974640143
#
#                author_id                                               text  \
# 11   1132055796571877376  Thread  about the cruel  in German  The debate...
# 105  1132055796571877376  Thread  summarizing a video by the German Fede...
# 125  1132055796571877376  On job  in German  and its impact on  life and...
# 215  1132055796571877376
# 238  1132055796571877376   German researchers without a permanent post i...
#
#      retweet_count  reply_count  like_count  quote_count  \
# 11               5            0          19            0
# 105              1            0           9            1
# 125              0            0           1            0
# 215              0            0           1            0
# 238              7            0          15            0
#
#                                      referenced_tweets  \
# 11   [{'type': 'quoted', 'id': '1405846267759054851'}]
# 105  [{'type': 'quoted', 'id': '1403006909079293953'}]
# 125  [{'type': 'quoted', 'id': '1402963684691955714'}]
# 215  [{'type': 'quoted', 'id': '1403059508021284864'}]
# 238  [{'type': 'quoted', 'id': '1402994337009442820'}]
#
#                                               hashtags tweet_type  \
# 11   ['precarity', 'academia', 'IchbinHanna', 'Acad...   original
# 105  ['IchbinHanna', 'academia', 'Germany', 'toxica...   original
# 125  ['precarity', 'academia', 'family', 'mentalhea...   original
# 215  ['AcademicTwitter', 'acertaindegreeofflexibili...   original
# 238  ['IchbinHanna', 'academia', 'AcademicTwitter',...   original
#
#     tweet_language                                            en_noun en_adj  \
# 11              en                                      thread debate
# 105             en  thread video ministry education research outcr...
# 125             en                                    job impact life
# 215             en
# 238             en  post comment job ministry education research s...
#
#     text_lemmatized_adj                               text_lemmatized_noun
# 11                   []                                   [thread, debate]
# 105                  []  [thread, video, ministry, education, research,...
# 125                  []                                [job, impact, life]
# 215                  []                                                 []
# 238                  []  [post, comment, job, ministry, education, rese...

# %%
en_df.drop(['text_lemmatized_adj'], axis=1)
en_df.head()
# Out:
#                     timestamp             tweet_id      conversation_id  \
# 11   2021-06-18T13:10:36.000Z  1405875593711964166  1405875593711964166
# 105  2021-06-12T21:15:23.000Z  1403823267115376649  1403823267115376649
# 125  2021-06-11T22:32:52.000Z  1403480380632674307  1403480380632674307
# 215  2021-06-10T19:07:52.000Z  1403066401611472902  1403066401611472902
# 238  2021-06-10T15:04:44.000Z  1403005214974640143  1403005214974640143
#
#                author_id                                               text  \
# 11   1132055796571877376  Thread  about the cruel  in German  The debate...
# 105  1132055796571877376  Thread  summarizing a video by the German Fede...
# 125  1132055796571877376  On job  in German  and its impact on  life and...
# 215  1132055796571877376
# 238  1132055796571877376   German researchers without a permanent post i...
#
#      retweet_count  reply_count  like_count  quote_count  \
# 11               5            0          19            0
# 105              1            0           9            1
# 125              0            0           1            0
# 215              0            0           1            0
# 238              7            0          15            0
#
#                                      referenced_tweets  \
# 11   [{'type': 'quoted', 'id': '1405846267759054851'}]
# 105  [{'type': 'quoted', 'id': '1403006909079293953'}]
# 125  [{'type': 'quoted', 'id': '1402963684691955714'}]
# 215  [{'type': 'quoted', 'id': '1403059508021284864'}]
# 238  [{'type': 'quoted', 'id': '1402994337009442820'}]
#
#                                               hashtags tweet_type  \
# 11   ['precarity', 'academia', 'IchbinHanna', 'Acad...   original
# 105  ['IchbinHanna', 'academia', 'Germany', 'toxica...   original
# 125  ['precarity', 'academia', 'family', 'mentalhea...   original
# 215  ['AcademicTwitter', 'acertaindegreeofflexibili...   original
# 238  ['IchbinHanna', 'academia', 'AcademicTwitter',...   original
#
#     tweet_language                                            en_noun en_adj  \
# 11              en                                      thread debate
# 105             en  thread video ministry education research outcr...
# 125             en                                    job impact life
# 215             en
# 238             en  post comment job ministry education research s...
#
#     text_lemmatized_adj                               text_lemmatized_noun
# 11                   []                                   [thread, debate]
# 105                  []  [thread, video, ministry, education, research,...
# 125                  []                                [job, impact, life]
# 215                  []                                                 []
# 238                  []  [post, comment, job, ministry, education, rese...

# %% [markdown]
# English LDA

# %%
def generate_tokens(tweet):
  words=[]
  for i in range(len(tweet)):
    word = tweet[i]
  # using the if condition because we introduced extra spaces during text cleaning
    if word!='':
      words.append(word)
  return words
#storing the generated tokens in a new column named 'words'
en_df['tokens'] = en_df.text_lemmatized_noun.apply(generate_tokens)
# Out:
# C:\Users\Moinam\AppData\Local\Temp\ipykernel_13908\2131270991.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   en_df['tokens'] = en_df.text_lemmatized_noun.apply(generate_tokens)

# %%
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

def create_dictionary(words):
  return corpora.Dictionary(words)
#passing the dataframe column having tokens as the argument
en_id2word = create_dictionary(en_df.tokens)
print(en_id2word)
# Out:
# Dictionary<3602 unique tokens: ['debate', 'thread', 'discussion', 'education', 'indignation']...>

# %%
def create_document_matrix(tokens, id2word):
  corpus = []
  for text in tokens:
    corpus.append(id2word.doc2bow(text))
  return corpus
#passing the dataframe column having tokens and dictionary
en_corpus = create_document_matrix(en_df.tokens, en_id2word)

# %%
en_lda_model = gensim.models.ldamodel.LdaModel(corpus=en_corpus, id2word=en_id2word, num_topics=10, random_state=100)

# %%
def get_lda_topics(model, num_topics, top_n_words):
     word_dict = {}
     for i in range(num_topics):
         word_dict['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in model.show_topic(i, topn = top_n_words)];
 
     return pd.DataFrame(word_dict)
get_lda_topics(en_lda_model,10,20)
# Out:
#      Topic # 01  Topic # 02  Topic # 03   Topic # 04  Topic # 05  \
# 0          post        year        link       thread          pm
# 1      position       right       click     academia    telegram
# 2      academia        lack      reward      seminar    movement
# 3    university       watch       video          way         law
# 4       article        link        form        class     science
# 5       channel      action      debate         need      career
# 6        system        life          uk   university    contract
# 7         youre        time       thing        sense         tag
# 8     professor  university   structure        topic    evidence
# 9         check     message    solution          lot        stop
# 10        stuff        cant       world      science  employment
# 11        group     comment   precarity       office   fixedterm
# 12   excellence        baby     history          end   stability
# 13         road          us     hashtag    selection  generation
# 14        party  experience         day   psychology        mark
# 15        death       guide       total        shock     display
# 16       policy      laptop       trend        shift        time
# 17  translation  technology       focus      disease     postdoc
# 18   politician        good      system  perspective  conference
# 19     progress  completion  collection     research        work
#
#         Topic # 06  Topic # 07    Topic # 08   Topic # 09  Topic # 10
# 0            music   situation      research     academia    academia
# 1           system    academia          goal          job        work
# 2         movement        time       airdrop      science        week
# 3           change     science          link         chat        time
# 4          program      career          hand          law     student
# 5         politics       brain          rate      project      future
# 6          service        chef          page      postdoc      tenure
# 7    casualisation  connection      security        world       track
# 8              lot      reason  distribution        tweet       paper
# 9             book   attention           job       market         job
# 10        academia  employment      academia      freedom         end
# 11          record        risk     professor        place         day
# 12        business         bin          time     research       money
# 13           cause        fact        number       public    contract
# 14               w    argument         level       fellow      reason
# 15          amount       nicht          term         feel  discussion
# 16  precariousness    employer          take         dont    research
# 17             lol          pi        system     position    industry
# 18         protest      system        stress          gig        side
# 19        audience       drain         price  recruitment     respect

# %% [markdown]
# Clustering for LDA ENglish

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(en_df.en_noun)
wcss = []
for i in range(1,101):
  kmeans = KMeans(n_clusters = i, init='k-means++', random_state=42)
  kmeans.fit(X)
  wcss.append(kmeans.inertia_)

plt.plot(range(1,101),wcss)
plt.title('Elbow method')
plt.xlabel(' No.of Clusters')
plt.ylabel(' WCSS')
plt.show()

# %%
#final cluster
clusters_en = KMeans(n_clusters = 35, init='k-means++', random_state=42)
clusters_en.fit(X)
# Out:
# KMeans(n_clusters=35, random_state=42)

# %%
print("Top terms per cluster:")
order_centroids = clusters_en.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(35):
    print ("Cluster %d:" % i)
    for ind in order_centroids[i, :5]:
        print (' %s' % terms[ind],)
    print
# Out:
# Top terms per cluster:
# Cluster 0:
#  core
#  experience
#  research
#  problem
#  system
# Cluster 1:
#  time
#  career
#  science
#  position
#  contract
# Cluster 2:
#  work
#  time
#  academia
#  research
#  salary
# Cluster 3:
#  researcher
#  career
#  academia
#  path
#  research
# Cluster 4:
#  support
#  academia
#  day
#  change
#  letter
# Cluster 5:
#  respect
#  system
#  science
#  framework
#  solidarity
# Cluster 6:
#  thread
#  academia
#  hashtag
#  hervorragender
#  whod
# Cluster 7:
#  situation
#  academia
#  thread
#  country
#  movement
# Cluster 8:
#  problem
#  system
#  academia
#  part
#  thats
# Cluster 9:
#  academia
#  time
#  career
#  law
#  precarity
# Cluster 10:
#  system
#  academia
#  position
#  precarity
#  uk
# Cluster 11:
#  word
#  tweet
#  support
#  solidarity
#  donation
# Cluster 12:
#  education
#  research
#  ministry
#  minister
#  uk
# Cluster 13:
#  struggle
#  academia
#  privilege
#  class
#  system
# Cluster 14:
#  tenure
#  track
#  professorship
#  position
#  system
# Cluster 15:
#  instance
#  grant
#  field
#  activism
#  cause
# Cluster 16:
#  question
#  system
#  position
#  politics
#  article
# Cluster 17:
#  future
#  system
#  research
#  family
#  contract
# Cluster 18:
#  bin
#  nicht
#  chef
#  bit
#  drain
# Cluster 19:
#  university
#  staff
#  system
#  time
#  research
# Cluster 20:
#  point
#  case
#  academia
#  hashtag
#  insecurity
# Cluster 21:
#  critique
#  fairy
#  ichbinhanna
#  mind
#  academia
# Cluster 22:
#  friend
#  email
#  playground
#  class
#  cypress
# Cluster 23:
#  book
#  system
#  cartoon
#  chapter
#  intersectionality
# Cluster 24:
#  gender
#  academia
#  gap
#  imbalance
#  analysis
# Cluster 25:
#  poverty
#  art
#  history
#  field
#  professor
# Cluster 26:
#  perspective
#  career
#  academia
#  situation
#  time
# Cluster 27:
#  discussion
#  panel
#  academia
#  career
#  meeting
# Cluster 28:
#  story
#  profile
#  message
#  interest
#  time
# Cluster 29:
#  inequality
#  system
#  pay
#  size
#  support
# Cluster 30:
#  job
#  market
#  security
#  academia
#  time
# Cluster 31:
#  research
#  time
#  academia
#  position
#  precarity
# Cluster 32:
#  petition
#  handover
#  academia
#  union
#  sign
# Cluster 33:
#  account
#  policy
#  demand
#  response
#  system
# Cluster 34:
#  badge
#  honour
#  case
#  way
#  envelope
# c:\Users\Moinam\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
final = []
for i in range(35):
  inner = []
  for j in order_centroids[i, ]:
    x = '%s' % terms[j]
    if (len(x) >2):  #removing single and double letters 
      inner.append(x)
  final.append(inner)

# %% [markdown]
# LDA on each clusters English

# %%
# for i in range(2):
#   print(final[i])

# %%
lmn = []
for i in range(35):
    en_cluster_dict = {"cluster": []}
    en_cluster_dict['cluster'] = final[i]
    lmn.append(en_cluster_dict)

# %%
# for i in range(2):
#   print(lmn[i])

# %%
en_cluster_df = pd.json_normalize(lmn)
en_cluster_df.head()
# Out:
#                                              cluster
# 0  [core, experience, research, problem, system, ...
# 1  [time, career, science, position, contract, ye...
# 2  [work, time, academia, research, salary, contr...
# 3  [researcher, career, academia, path, research,...
# 4  [support, academia, day, change, letter, inter...

# %%
def cluster_create_dictionary(words):
  return corpora.Dictionary(words)
#passing the dataframe column having tokens as the argument
cluster_en_id2word = create_dictionary(en_cluster_df.cluster)
print(cluster_en_id2word)
# Out:
# Dictionary<3612 unique tokens: ['_while', '_wish_', 'abandon', 'ability', 'ableism']...>

# %%
def cluster_create_document_matrix(tokens, id2word):
  corpus = []
  for text in tokens:
    corpus.append(id2word.doc2bow(text))
  return corpus
#passing the dataframe column having tokens and dictionary
cluster_en_corpus = cluster_create_document_matrix(en_cluster_df.cluster, cluster_en_id2word)

# %%
cluster_en_lda_model = gensim.models.ldamodel.LdaModel(corpus=cluster_en_corpus, id2word=cluster_en_id2word, num_topics=10, random_state=100)

# %%
def get_lda_topics(model, num_topics, top_n_words):
     word_dict = {}
     for i in range(num_topics):
         word_dict['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in model.show_topic(i, topn = top_n_words)];
 
     return pd.DataFrame(word_dict)
get_lda_topics(cluster_en_lda_model,10,20)
# Out:
#              Topic # 01        Topic # 02  Topic # 03           Topic # 04  \
# 0         appropriation             theyd   criterion           depression
# 1              approval  misunderstanding    tokenism         illustration
# 2              bathroom     countersystem    burntout               backup
# 3             imbalance             robot       cause            breathing
# 4    institutionscholar             genre   attendant         whataboutism
# 5             pollutant          citation        mess               poster
# 6               dialect          preprint      saying                 fury
# 7             judgement               tbr     madness                 give
# 8              oppinion         monastery      wakeup          vaccination
# 9                 money              soll   ecologist             dialogue
# 10                 gift               tip    disgrace                irony
# 11             boldness             board    youtuber                  cat
# 12              pastime     constellation       focus             assembly
# 13           excitement              outs        span          expectation
# 14  relationsuniversity            crypto        wage                grasp
# 15                 name           hygiene      method  professionalisation
# 16            narrative            fellow    panorama                 bait
# 17               resume           network  livelihood                 weve
# 18             feelgood              kind     teacher                 nach
# 19              anguish       dysfunction      coming              journal
#
#          Topic # 05              Topic # 06     Topic # 07    Topic # 08  \
# 0       celebration              television          claim     explosion
# 1     documentation            datafication        pasting    graduating
# 2       personality                 sadness       overhaul      boldness
# 3            racism               organiser           loan      exposure
# 4       selftorture             institution         stable          pain
# 5       legislation            neuroscience          click          pity
# 6     uncertaintity                     bed      whiteness    backtoback
# 7         paperback                 culling          title      roadside
# 8        commitment                 iceberg           hack          wave
# 9          graphics                  mentor           desk         magic
# 10         baseline                     rug         glance     interview
# 11        tiredness                moodjust      shitstorm          post
# 12       evaluation                    poet    reciprocity      analysis
# 13           fringe  wissenschftsmanagement          chime          song
# 14         backfire              onboarding     electorate  conditioning
# 15        unbalance                     gut  employability        lolsob
# 16              pig                 persona            org      strategy
# 17         fallback                 dissent        hrsweek     classroom
# 18        shortterm                  talent      celebrity     consortia
# 19  diversification                  answer      newspaper   meritocracy
#
#            Topic # 09             Topic # 10
# 0        twitterstorm                academy
# 1             economy             likability
# 2         itprofessur            probability
# 3               owner             fuckademia
# 4                tape         characteristic
# 5               tweet                  power
# 6       interviewhire                   drag
# 7   durchlauferhitzer  ausgründungsprofessur
# 8       meteorologist           privatdozent
# 9              behalf               metaphor
# 10              ratio                  speed
# 11          réception                removal
# 12       satisfaction             corruption
# 13           ceremony             confidence
# 14        sponsorship                 chance
# 15           workwork                 podium
# 16          comentary               contempt
# 17              decay               litteram
# 18             result                   navy
# 19                bus               survivor

# %% [markdown]
# Cluster's LDA English

# %%
for i in range(27):
  clust_id2_word = create_dictionary([final[i]])
  clust_corpus = cluster_create_document_matrix([final[i]], clust_id2_word)
  clust_lda_model = gensim.models.ldamodel.LdaModel(corpus=clust_corpus, id2word=clust_id2_word, num_topics=10, random_state=100)
  print("Cluster", i+1," :")
  print(get_lda_topics(clust_lda_model,10,10))
  print("************************************ \n")
# Out:
# Cluster 1  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 2  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 3  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 4  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 5  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 6  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 7  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 8  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 9  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 10  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 11  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 12  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 13  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 14  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 15  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 16  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 17  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 18  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 19  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 20  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 21  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 22  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 23  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 24  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 25  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 26  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
#
# Cluster 27  :
#            Topic # 01        Topic # 02 Topic # 03    Topic # 04  \
# 0       appropriation             theyd  criterion    depression
# 1  institutionscholar     countersystem   tokenism  illustration
# 2            bathroom  misunderstanding  attendant        backup
# 3            approval             genre   burntout     breathing
# 4           imbalance             robot       mess  whataboutism
# 5           pollutant          citation      cause        poster
# 6             dialect               tbr     saying          fury
# 7           judgement         monastery    madness   vaccination
# 8            oppinion              soll   disgrace          give
# 9               money               tip     wakeup      dialogue
#
#       Topic # 05    Topic # 06   Topic # 07  Topic # 08         Topic # 09  \
# 0  documentation    television        claim  graduating       twitterstorm
# 1    celebration  datafication      pasting   explosion            economy
# 2    personality       sadness         loan    boldness               tape
# 3         racism     organiser     overhaul    exposure        itprofessur
# 4    selftorture   institution       stable        pity              owner
# 5      paperback           bed         hack  backtoback              tweet
# 6    legislation  neuroscience    whiteness    roadside  durchlauferhitzer
# 7     commitment       iceberg        title        pain      meteorologist
# 8  uncertaintity        mentor        click        wave      interviewhire
# 9       graphics    onboarding  reciprocity    analysis              ratio
#
#               Topic # 10
# 0                academy
# 1             likability
# 2            probability
# 3             fuckademia
# 4         characteristic
# 5                  power
# 6           privatdozent
# 7  ausgründungsprofessur
# 8                   drag
# 9                removal
# ************************************
